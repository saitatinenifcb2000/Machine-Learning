# %% [markdown]
# # Implementing market basket analysis

# %%
#Loading neccesary packages
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
#Reading Data From Web
myretaildata = pd.read_excel('Online Retail.xlsx')
myretaildata.shape
# Out:
# (1128, 8)

# %% [markdown]
# # Data Preparation

# %%
#Data Cleaning
myretaildata['Description'] = myretaildata['Description'].str.strip() #removes spaces from beginning and end
myretaildata.dropna(axis=0, subset=['InvoiceNo'], inplace=True) #removes duplicate invoice
myretaildata['InvoiceNo'] = myretaildata['InvoiceNo'].astype('str') #converting invoice number to be string
myretaildata = myretaildata[~myretaildata['InvoiceNo'].str.contains('C')] #remove the credit transactions 
myretaildata.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
myretaildata.shape
# Out:
# (1118, 8)

# %%
myretaildata['Country'].value_counts()
# Out:
# United Kingdom    1067
# France              20
# Germany             15
# Australia           14
# Netherlands          2
# Name: Country, dtype: int64

# %%
#Separating transactions for United Kingdom
mybasket = (myretaildata[myretaildata['Country'] =="United Kingdom"].groupby(['InvoiceNo', 'Description'])['Quantity'].sum()
            .unstack().reset_index().fillna(0).set_index('InvoiceNo'))u

# %%
#viewing transaction basket
mybasket.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 DAISY PEGS IN WOOD BOX  \
# InvoiceNo
# 536365                          0.0                        0.0
# 536366                          0.0                        0.0
# 536367                          0.0                        0.0
# 536368                          0.0                        0.0
# 536369                          0.0                        0.0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536365                                   0.0                            0.0
# 536366                                   0.0                            0.0
# 536367                                   0.0                            0.0
# 536368                                   0.0                            0.0
# 536369                                   0.0                            0.0
#
# Description  12 PENCILS SMALL TUBE SKULL  12 PENCILS TALL TUBE SKULLS  \
# InvoiceNo
# 536365                               0.0                          0.0
# 536366                               0.0                          0.0
# 536367                               0.0                          0.0
# 536368                               0.0                          0.0
# 536369                               0.0                          0.0
#
# Description  3 PIECE SPACEBOY COOKIE CUTTER SET  3 STRIPEY MICE FELTCRAFT  \
# InvoiceNo
# 536365                                      0.0                       0.0
# 536366                                      0.0                       0.0
# 536367                                      0.0                       0.0
# 536368                                      0.0                       0.0
# 536369                                      0.0                       0.0
#
# Description  3 TIER CAKE TIN GREEN AND CREAM  3 TIER CAKE TIN RED AND CREAM  \
# InvoiceNo
# 536365                                   0.0                            0.0
# 536366                                   0.0                            0.0
# 536367                                   0.0                            0.0
# 536368                                   0.0                            0.0
# 536369                                   0.0                            0.0
#
# Description  ...  WOODEN FRAME ANTIQUE WHITE  \
# InvoiceNo    ...
# 536365       ...                         0.0
# 536366       ...                         0.0
# 536367       ...                         0.0
# 536368       ...                         0.0
# 536369       ...                         0.0
#
# Description  WOODEN HEART CHRISTMAS SCANDINAVIAN  WOODEN OWLS LIGHT GARLAND  \
# InvoiceNo
# 536365                                       0.0                        0.0
# 536366                                       0.0                        0.0
# 536367                                       0.0                        0.0
# 536368                                       0.0                        0.0
# 536369                                       0.0                        0.0
#
# Description  WOODEN PICTURE FRAME WHITE FINISH  WRAP COWBOYS  \
# InvoiceNo
# 536365                                     0.0           0.0
# 536366                                     0.0           0.0
# 536367                                     0.0           0.0
# 536368                                     0.0           0.0
# 536369                                     0.0           0.0
#
# Description  YELLOW BREAKFAST CUP AND SAUCER  YELLOW COAT RACK PARIS FASHION  \
# InvoiceNo
# 536365                                   0.0                             0.0
# 536366                                   0.0                             0.0
# 536367                                   0.0                             0.0
# 536368                                   0.0                             3.0
# 536369                                   0.0                             0.0
#
# Description  YOU'RE CONFUSING ME METAL SIGN  ZINC METAL HEART DECORATION  \
# InvoiceNo
# 536365                                  0.0                          0.0
# 536366                                  0.0                          0.0
# 536367                                  0.0                          0.0
# 536368                                  0.0                          0.0
# 536369                                  0.0                          0.0
#
# Description  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo
# 536365                                    0.0
# 536366                                    0.0
# 536367                                    0.0
# 536368                                    0.0
# 536369                                    0.0
#
# [5 rows x 621 columns]

# %%
#converting all positive vaues to 1 and everything else to 0
def my_encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

my_basket_sets = mybasket.applymap(my_encode_units)

# %%
my_basket_sets.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 DAISY PEGS IN WOOD BOX  \
# InvoiceNo
# 536365                            0                          0
# 536366                            0                          0
# 536367                            0                          0
# 536368                            0                          0
# 536369                            0                          0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536365                                     0                              0
# 536366                                     0                              0
# 536367                                     0                              0
# 536368                                     0                              0
# 536369                                     0                              0
#
# Description  12 PENCILS SMALL TUBE SKULL  12 PENCILS TALL TUBE SKULLS  \
# InvoiceNo
# 536365                                 0                            0
# 536366                                 0                            0
# 536367                                 0                            0
# 536368                                 0                            0
# 536369                                 0                            0
#
# Description  3 PIECE SPACEBOY COOKIE CUTTER SET  3 STRIPEY MICE FELTCRAFT  \
# InvoiceNo
# 536365                                        0                         0
# 536366                                        0                         0
# 536367                                        0                         0
# 536368                                        0                         0
# 536369                                        0                         0
#
# Description  3 TIER CAKE TIN GREEN AND CREAM  3 TIER CAKE TIN RED AND CREAM  \
# InvoiceNo
# 536365                                     0                              0
# 536366                                     0                              0
# 536367                                     0                              0
# 536368                                     0                              0
# 536369                                     0                              0
#
# Description  ...  WOODEN FRAME ANTIQUE WHITE  \
# InvoiceNo    ...
# 536365       ...                           0
# 536366       ...                           0
# 536367       ...                           0
# 536368       ...                           0
# 536369       ...                           0
#
# Description  WOODEN HEART CHRISTMAS SCANDINAVIAN  WOODEN OWLS LIGHT GARLAND  \
# InvoiceNo
# 536365                                         0                          0
# 536366                                         0                          0
# 536367                                         0                          0
# 536368                                         0                          0
# 536369                                         0                          0
#
# Description  WOODEN PICTURE FRAME WHITE FINISH  WRAP COWBOYS  \
# InvoiceNo
# 536365                                       0             0
# 536366                                       0             0
# 536367                                       0             0
# 536368                                       0             0
# 536369                                       0             0
#
# Description  YELLOW BREAKFAST CUP AND SAUCER  YELLOW COAT RACK PARIS FASHION  \
# InvoiceNo
# 536365                                     0                               0
# 536366                                     0                               0
# 536367                                     0                               0
# 536368                                     0                               1
# 536369                                     0                               0
#
# Description  YOU'RE CONFUSING ME METAL SIGN  ZINC METAL HEART DECORATION  \
# InvoiceNo
# 536365                                    0                            0
# 536366                                    0                            0
# 536367                                    0                            0
# 536368                                    0                            0
# 536369                                    0                            0
#
# Description  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo
# 536365                                      0
# 536366                                      0
# 536367                                      0
# 536368                                      0
# 536369                                      0
#
# [5 rows x 621 columns]

# %% [markdown]
# # Training Model

# %%
#Generatig frequent itemsets
my_frequent_itemsets = apriori(my_basket_sets, min_support=0.075, use_colnames=True)

# %%
#generating rules
my_rules = association_rules(my_frequent_itemsets, metric="lift", min_threshold=1)

# %%
my_rules.shape
# Out:
# (1936, 9)

# %%
#viewing Top 5 rules
my_rules.sort_values(by = "lift", ascending = False)[:5]
# Out:
#                                             antecedents  \
# 0                   (GLASS STAR FROSTED T-LIGHT HOLDER)
# 1245  (WHITE METAL LANTERN, GLASS STAR FROSTED T-LIG...
# 1262  (KNITTED UNION FLAG HOT WATER BOTTLE, GLASS ST...
# 1261  (KNITTED UNION FLAG HOT WATER BOTTLE, WHITE ME...
# 1258  (RED WOOLLY HOTTIE WHITE HEART., KNITTED UNION...
#
#                                             consequents  antecedent support  \
# 0                      (CREAM CUPID HEARTS COAT HANGER)            0.076923
# 1245  (RED WOOLLY HOTTIE WHITE HEART., KNITTED UNION...            0.076923
# 1262  (RED WOOLLY HOTTIE WHITE HEART., WHITE METAL L...            0.076923
# 1261  (RED WOOLLY HOTTIE WHITE HEART., GLASS STAR FR...            0.076923
# 1258                              (WHITE METAL LANTERN)            0.076923
#
#       consequent support   support  confidence  lift  leverage  conviction
# 0               0.076923  0.076923         1.0  13.0  0.071006         inf
# 1245            0.076923  0.076923         1.0  13.0  0.071006         inf
# 1262            0.076923  0.076923         1.0  13.0  0.071006         inf
# 1261            0.076923  0.076923         1.0  13.0  0.071006         inf
# 1258            0.076923  0.076923         1.0  13.0  0.071006         inf

# %% [markdown]
# # Making recommendations

# %%
#Filtering rules based on condition
my_rules[(my_rules['lift'] >= 3) &
       (my_rules['confidence'] >= 0.8)]
# Out:
#                                 antecedents  \
# 0       (GLASS STAR FROSTED T-LIGHT HOLDER)
# 1          (CREAM CUPID HEARTS COAT HANGER)
# 2     (KNITTED UNION FLAG HOT WATER BOTTLE)
# 3          (CREAM CUPID HEARTS COAT HANGER)
# 5          (CREAM CUPID HEARTS COAT HANGER)
# ...                                     ...
# 1929  (KNITTED UNION FLAG HOT WATER BOTTLE)
# 1930       (CREAM CUPID HEARTS COAT HANGER)
# 1932                  (WHITE METAL LANTERN)
# 1933    (GLASS STAR FROSTED T-LIGHT HOLDER)
# 1935         (SET 7 BABUSHKA NESTING BOXES)
#
#                                             consequents  antecedent support  \
# 0                      (CREAM CUPID HEARTS COAT HANGER)            0.076923
# 1                   (GLASS STAR FROSTED T-LIGHT HOLDER)            0.076923
# 2                      (CREAM CUPID HEARTS COAT HANGER)            0.092308
# 3                 (KNITTED UNION FLAG HOT WATER BOTTLE)            0.076923
# 5                      (RED WOOLLY HOTTIE WHITE HEART.)            0.076923
# ...                                                 ...                 ...
# 1929  (CREAM CUPID HEARTS COAT HANGER, WHITE HANGING...            0.092308
# 1930  (KNITTED UNION FLAG HOT WATER BOTTLE, WHITE HA...            0.076923
# 1932  (KNITTED UNION FLAG HOT WATER BOTTLE, CREAM CU...            0.076923
# 1933  (KNITTED UNION FLAG HOT WATER BOTTLE, CREAM CU...            0.076923
# 1935  (KNITTED UNION FLAG HOT WATER BOTTLE, CREAM CU...            0.092308
#
#       consequent support   support  confidence       lift  leverage  \
# 0               0.076923  0.076923    1.000000  13.000000  0.071006
# 1               0.076923  0.076923    1.000000  13.000000  0.071006
# 2               0.076923  0.076923    0.833333  10.833333  0.069822
# 3               0.092308  0.076923    1.000000  10.833333  0.069822
# 5               0.138462  0.076923    1.000000   7.222222  0.066272
# ...                  ...       ...         ...        ...       ...
# 1929            0.076923  0.076923    0.833333  10.833333  0.069822
# 1930            0.076923  0.076923    1.000000  13.000000  0.071006
# 1932            0.076923  0.076923    1.000000  13.000000  0.071006
# 1933            0.076923  0.076923    1.000000  13.000000  0.071006
# 1935            0.076923  0.076923    0.833333  10.833333  0.069822
#
#       conviction
# 0            inf
# 1            inf
# 2       5.538462
# 3            inf
# 5            inf
# ...          ...
# 1929    5.538462
# 1930         inf
# 1932         inf
# 1933         inf
# 1935    5.538462
#
# [1808 rows x 9 columns]
